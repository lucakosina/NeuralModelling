# %% [markdown]
# # Assignement 2
# Submission Group: Luca Kosina (6084778), Sascha Mühlinghaus (7075485)
#
# ### Part 1: Conditioning (Lecture 2)

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
# implementing paradigms with Rescorla-Wagner model:
# new_weight = alpha * (reward - (stim * weight)) * stim

def update_expectation(weight, stim, reward, alpha=0.1, beta=0.1):
    """
    Update the expectation based on two stimuli and a reward/punishment according to Rescorla-Wagner learning rule.

    Parameters:
    weight (array): List of weights for each stimulus.
    stim (array): Array of stimuli presentations.
    reward (array): The received reward or punishment.
    alpha (float): The learning rate for stimulus 1.
    beta (float): The learning rate for stimulus 2.

    Returns:
    tuple: The updated weight(s) and delta value.
    """
    if np.isscalar(stim):
        # compute value
        value = weight * stim
        # calculate prediction/expectation/delta error
        delta = reward - value  # sum to avoid broadcasting issues
        # update expectations
        weight += alpha * delta * stim  # scalar stim used
        return weight, delta, value
    else:
        # compute value
        value = weight[0] * stim[0] + weight[1] * stim[1]
        # calculate prediction/expectation/delta error
        delta = reward - np.sum(value)  # sum to avoid broadcasting issues
        # update expectations
        weight[0] += alpha * delta * stim[0]  # scalar stim[0] used
        weight[1] += beta * delta * stim[1]   # scalar stim[1] used
        return weight[0], weight[1], delta, value

# %% [markdown]
# ### Interpretation Training-Blocking-Paradigm:
# For the blocking paradigm the Rescorla-Wagner model approaches the idealized expectation. Hence, the model accounts for the behaviour of the animal realistically.

# %%
n_trials = 100  # number of trials
weights = [0, 0]  # initial weights for two stimuli
stim_blocking = np.array([np.ones(n_trials), np.zeros(n_trials)])  # stimuli for blocking paradigm
reward = np.ones(n_trials)  # reward for blocking paradigm
w1_list = [weights[0]]  # initialize weight list for stimulus 1
alpha = 0.1  # learning rate for stimulus 1
beta = 0.1   # learning rate for stimulus 2

# idealized expectation for blocking paradigm
stimuli_us = np.ones(100)
stimuli_cs = np.ones(100)

idealized_expectation = np.ones(n_trials)

# pre-training for blocking paradigm
for i in range(1, n_trials):
    # update expectation
    w1, w2, delta, value = update_expectation(weights, stim_blocking[:,i], reward[i], alpha, beta)
    # append the weight for stimulus 1
    w1_list.append(w1)


# idealized expectation of reward
expectation = 1 - np.exp(-alpha*np.arange(n_trials))

# Plot the weights over trials
plt.plot(w1_list, label='weight 1')
plt.plot(expectation, label="Expectation of Reward ", color="red", linestyle='--')
plt.xlabel("Trials")
plt.ylabel("Weight Value")
plt.legend()
plt.title("Pretraining: Blocking Paradigm")
plt.show()

# %%
weights = [w1, 0] # initial weights for two stimuli

w1_list = [weights[0]] # initialize weight list 1
w2_list = [weights[1]] # initialize weight list 2

idealized_expectation1 = np.array([1]*n_trials)  # idealized expectation for weight 1
idealized_expectation2 = np.array([0]*n_trials)  # idealized expectation for weight 2

# blocking paradigm 
for i in range(1, n_trials):
    # update expectation
    w1, w2, delta, value = update_expectation(weights, stim_blocking[:,i], reward[i], alpha, beta)
    # append to weight lists
    w1_list.append(w1)
    w2_list.append(w2)


# Plot the weights over trials
plt.plot(w1_list, label='weight 1')
plt.plot(w2_list, label='weight 2')
plt.plot(idealized_expectation1, label='idealized expectation', linestyle='--', color='red')
plt.scatter(101, value, label='Test Prediction')
plt.xlabel("Trials")
plt.ylabel("Weight Value")
plt.legend()
plt.title("Training: Blocking Paradigm")
plt.show()

# %% [markdown]
# ### Interpretation Inhibitory Conditioning Paradigm:
# Depending on the learning rate and number of trials it may take longer or shorter for the weights to converge toward the idealized expectations. Rascorla-Wagner also accounts for this paradigm.

# %%
weights = [0, 0] # initial weight for stimulus 2
w1_list = [weights[0]] # initialize weight list 1
w2_list = [weights[1]] # initialize weight list 2
n_trials = 100 # number of trials
alpha = 0.2 # learning rate for stimulus 1
beta = 0.2 # learning rate for stimulus 2

# generate inhibitory conditioning stimuli 
stim_inhib = np.array([np.ones(n_trials), [0, 1]*50])

idealized_expectation1 = np.array([1]*n_trials)  # idealized expectation for weight 1
idealized_expectation2 = np.array([-1]*n_trials)  # idealized expectation for weight 2

# generate reward
reward = np.array([1, 0]*100)
# inhibitory conditioning paradigm 
for i in range(1, n_trials):
    # update expectation
    w1, w2, delta, value = update_expectation(weights, stim_inhib[:,i], reward[i], alpha, beta)
    # append to weight lists
    w1_list.append(w1)
    w2_list.append(w2)


# idealized expectation of reward
#expectation = 1 - np.exp(-alpha*np.arange(n_trials))
expectation = w1_list * np.array(np.tile([0,1], int(n_trials/2)))

# Plot the weights over trials
plt.plot(w1_list, label='weight 1')
plt.plot(w2_list, label='weight 2')
plt.plot(expectation, label="Expectation of Reward ", color="red", linestyle=':')
plt.scatter(101, value, label='Test Prediction')
plt.xlabel("Trials")
plt.ylabel("Weight Value")
plt.legend()
plt.title("Training: Inhibitory Conditioning Paradigm")
plt.show()

# %% [markdown]
# ### Interpretation Overshadowing Paradigm:
# Again for the overshadowing the weights approach the expected values. The expected values in the overshadowing paradigm are proportional to the difference in learning rate (alpha, beta). Rescorla-Wagner also accounts for this paradigm.

# %%
weights = [0, 0] # initial weight for stimulus 2
w1_list = [weights[0]] # initialize weight list 1
w2_list = [weights[1]] # initialize weight list 2

n_trials = 100

alpha = 0.1 # learning rate for stimulus 1
beta = 0.2 # learning rate for stimulus 2

idealized_expectation1 = np.array([.666]*n_trials)  # idealized expectation for weight 1
idealized_expectation2 = np.array([.333]*n_trials)  # idealized expectation for weight 2

# generate overshadowing stimuli 
stim_overshad = np.array([np.ones(n_trials), np.ones(n_trials)])  # stimuli for blocking paradigm
# generate reward
reward = np.ones(n_trials)
# overshadowing paradigm 
for i in range(1, n_trials):
   # update expectation
    w1, w2, delta, value = update_expectation(weights, stim_overshad[:,i], reward[i], alpha, beta)
    # append to weight lists
    w1_list.append(w1)
    w2_list.append(w2)

# Plot the weights over trials
plt.plot(w1_list, label='weight 1')
plt.plot(w2_list, label='weight 2')
plt.plot(expectation, label="Expectation of Reward ", color="red", linestyle='--')
plt.scatter(101, value, label='Test Prediction')
plt.xlabel("Trials")
plt.ylabel("Weight Value")
plt.legend()
plt.title("Training: Overshadowing Paradigm")
plt.show()

# %% [markdown]
# ### Interpretation Secondary Conditioning Paradigm:
# During the pretraining the weight approaches the idealized expectation following an exponential function. However, the Rescorla-Wagner does not account for the secondary conditioning paradigm because it is uncapable of associating predictors of rewards with a reward. Therefore, the indirect coupling of S2 predicting S1 and S1 predicting the reward does not work.

# %%
# pre-training for secondary conditioning paradigm
n_trials = 100
weights = [0, 0] # initial weight for stimulus 2
w1_list = [weights[0]] # initialize weight list 1
w2_list = [weights[1]] # initialize weight list 2
reward = np.ones(n_trials) # reward for secondary conditioning paradigm

idealized_expectation1 = np.array([1]*n_trials)  # idealized expectation for weight 1

stim_sec = np.array([np.ones(n_trials), np.zeros(n_trials)]) # stimuli for secondary conditioning paradigm
alpha = 0.1 # learning rate for stimulus 1
beta = 0.1 # learning rate for stimulus 2
for i in range(n_trials):
    # update expectation
    w1, w2, delta, value = update_expectation(weights, stim_sec[:,i], reward[i], alpha, beta)
    # append to weight lists
    w1_list.append(w1)
    w2_list.append(w2)



# idealized expectation of reward
expectation = 1 - np.exp(-alpha*np.arange(n_trials))

# Plot the weights over trials
plt.plot(w1_list, label='weight 1')
plt.plot(expectation, label="Expectation of Reward ", color="red", linestyle='--')
plt.xlabel("Trials")
plt.ylabel("Weight Value")
plt.legend()
plt.title("Pretraining: Secondary Conditioning Paradigm")
plt.show()

# %%
weights = [w1, 0] # initial weight for stimulus 2

w1_list = [weights[0]] # initialize weight list 1
w2_list = [weights[1]] # initialize weight list 2
alpha = 0.1 # learning rate for stimulus 1
beta = 0.1 # learning rate for stimulus 2

reward = np.ones(n_trials) # reward for secondary conditioning paradigm

idealized_expectation1 = np.array([1]*n_trials)  # idealized expectation for weight 1
idealized_expectation2 = np.array([1]*n_trials)  # idealized expectation for weight 2

# secondary conditioning paradigm
for i in range(n_trials):
    # update expectation
    w1, w2, delta, value = update_expectation(weights, stim_sec[:,i], reward[i], alpha, beta)
    # append to weight lists
    w1_list.append(w1)
    w2_list.append(w2)

# Plot the weights over trials
plt.plot(w1_list, label='weight 1')
plt.plot(w2_list, label='weight 2')
plt.plot(idealized_expectation1, label='idealized expectation', linestyle='--', color='red')
plt.scatter(101, value, label='Test Prediction')
plt.xlabel("Trials")
plt.ylabel("Weight Value")
plt.legend()
plt.title("Training: Secondary Conditioning Paradigm")
plt.show()

# %% [markdown]
# ### Interpretation of Explaining-away Paradigm:
# The intuition of the explaining away paradigm is not captured by Rescorla-Wagner because (same reasoning as for the previous) the model cannot account for negative or positive predictive relationships between multiple stimuli.

# %%
# explaining away paradigm
n_trials = 100
weights = [0, 0] # initial weight for stimulus 2
w1_list = [weights[0]] # initialize weight list 1
w2_list = [weights[1]] # initialize weight list 2

alpha = 0.1 # learning rate for stimulus 1
beta = 0.1 # learning rate for stimulus 2
reward = np.ones(n_trials) # reward for explaining away paradigm

idealized_expectation1 = np.array([1]*n_trials)  # idealized expectation for weight 1
idealized_expectation2 = np.concatenate([np.ones(50), np.zeros(50)])  # idealized expectation for weight 2

w1 = 0 # initial expectation
w2 = 0 # initial expectation
stim_exp = np.array([np.ones(n_trials), np.concatenate([np.ones(50), np.zeros(50)])]) # stimuli for explaining away paradigm

# explaining away paradigm
for i in range(n_trials):
    # update expectation
    w1, w2, delta, value = update_expectation(weights, stim_exp[:,i], reward[i], alpha, beta)
    # append to weight lists
    w1_list.append(w1)
    w2_list.append(w2)

# idealized expectation of reward
expectation = 1 - np.exp(-alpha*np.arange(n_trials))

# Plot the weights over trials
plt.plot(w1_list, label='weight 1')
plt.plot(w2_list, label='weight 2')
plt.plot(expectation, label="Expectation of Reward ", color="red", linestyle='--')
plt.scatter(101, value, label='Test Prediction')
plt.xlabel("Trials")
plt.ylabel("Weight Value")
plt.legend()
plt.title("Training: Explaining Away Paradigm")
plt.show()

# %% [markdown]
# ## Part 2: Extinction (Lecture 3)

# %% [markdown]
# ### Interpretation of State based Inference:
#
#
# For the first 50 trials the animal learns that the stimulus predicts a punishment, hence the weight of belief 1 is recursively updated and increases punishment prediction (for simplicity the punishment is represented by a positive value). When entering the second half of the training, the stimulus is not paired with the punishment anymore. Therefore, the weight of the belief of state 1 decreases until the probability of being in state 1 is below .5. The weight of state 2 which represents the no punishment state is updated but because there is no punishment it remains zero. This serves the purpose of integrating changing latent causes into our predictiion.

# %%
# Define the number of trials
n_trials_day1 = 50
n_trials_day2 = 50
gap_days = 30
total_trials = n_trials_day1 + n_trials_day2 + 1  # 101 trials in total

# Create the temporal difference array
temporal_differences = np.zeros(total_trials)
temporal_differences[n_trials_day1] = 1  # 1-day difference between last trial of day 1 and first trial of day 2
temporal_differences[99] = gap_days  # 30-day difference to the last trial on day 33

# %%
true_state = np.array(np.concatenate([[1]*50, [0]*51, [0]]))

def state_heuristic(previous_state, similarity, delay):
    # calculate the probability of the current state
    probability = similarity*delay
    # calculate the probability of the other state
    prob_different_state = (1 - similarity)*delay 

    # calculate the probability of each state
    prob_state_1 = previous_state*probability + (1-probability)*prob_different_state
    prob_state_2 = previous_state*prob_different_state + (1-probability)*probability
    
    probability = prob_state_1 / (prob_state_1 + prob_state_2)

    # switch states if probability for previous state is below .5
    if probability < 0.5:
        if previous_state == 0.1 or previous_state == 0:
            current_state = 1
        else:
            current_state = 0
    else:
        current_state = previous_state

    return probability, current_state

# %%
# initialize belief arrays
belief_state1 = np.concatenate([[0] * 50, np.full(52, np.nan)])
belief_state2 = np.array([0] * (total_trials+1))

# initialize stimulus & reward arrays
experimental_stim = np.ones(total_trials+1)
experimental_reward = np.concatenate([np.ones(50), np.zeros(52), [0]])

current_state = 0.1
similarity = 1
delay_term = 1

alpha = 0.1
beta = 0.1

prob1 = []
prob2 = []

for i in range(1, total_trials+1):
    print('delay:', delay)
    # update the current belief state and probability
    probability, current_state = state_heuristic(current_state, similarity, delay_term)
    print(f'Trial {i}, Probability: {probability}, Current State: {current_state}, delay: {delay_term}')
    if current_state == 0.1:
        prob1.append(probability)
        prob2.append(1-probability)
    else:
        prob1.append(1-probability)
        prob2.append(probability)
    # factor for scaling the delay 
    scaling_factor = 1

    # update the delay 
    delay_term = 1 / (1 + (temporal_differences[i-1] * scaling_factor))
    
    # if stimuli are equal in two consecutive trials then similarity is 1
    if experimental_stim[i] == experimental_stim[i-1] and experimental_reward[i] == experimental_reward[i-1]:
        similarity = 1 
    else:
        similarity = 0

    # switch state if probability for previous state is <.5 and update reward predictions 
    if probability > 0.5 and current_state == 0.1:
        prediction, delta, prediction = update_expectation(belief_state1[i-1], experimental_stim[i], experimental_reward[i], alpha, beta)
        belief_state1[i] = prediction * probability
        
    else:
        prediction, delta, prediction = update_expectation(belief_state2[i-1], experimental_stim[i], experimental_reward[i], alpha, beta)
        belief_state2[i] = prediction * probability
        belief_state1[i] = belief_state1[i-1]
    

# Create a figure with two subplots 
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6), sharey=True)
fig.suptitle("Training: State based inference")
# Plot 1
ax1.plot(belief_state1, label='belief state 1')
ax1.plot(belief_state2, label='belief state 2')
ax1.plot(true_state, label='true_state', linestyle=':', color='green')
ax1.set_xlabel("Trials")
ax1.set_ylabel("weights / state")
ax1.legend()

# Plot 2
ax2.plot(prob1, label='probability for state 1', linestyle='--', color='purple')
ax2.plot(prob2, label='probability for state 2', linestyle='--', color='green')
ax2.set_xlabel("Trials")
ax2.set_ylabel("probabality [0 - 1]")
ax2.legend()

plt.tight_layout()
plt.show()
# Out:
# delay: 1
# Trial 1, Probability: 1.0, Current State: 0.1, delay: 1
# State1: Prediction=0.1, Delta=1.0, Belief State 1[1]=0.1
# delay: 1
# Trial 2, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.19, Delta=0.9, Belief State 1[2]=0.19
# delay: 1
# Trial 3, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.271, Delta=0.81, Belief State 1[3]=0.271
# delay: 1
# Trial 4, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.34390000000000004, Delta=0.729, Belief State 1[4]=0.34390000000000004
# delay: 1
# Trial 5, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.40951000000000004, Delta=0.6560999999999999, Belief State 1[5]=0.40951000000000004
# delay: 1
# Trial 6, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.46855900000000006, Delta=0.59049, Belief State 1[6]=0.46855900000000006
# delay: 1
# Trial 7, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.5217031000000001, Delta=0.5314409999999999, Belief State 1[7]=0.5217031000000001
# delay: 1
# Trial 8, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.5695327900000001, Delta=0.4782968999999999, Belief State 1[8]=0.5695327900000001
# delay: 1
# Trial 9, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.6125795110000001, Delta=0.4304672099999999, Belief State 1[9]=0.6125795110000001
# delay: 1
# Trial 10, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.6513215599000001, Delta=0.3874204889999999, Belief State 1[10]=0.6513215599000001
# delay: 1
# Trial 11, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.68618940391, Delta=0.34867844009999993, Belief State 1[11]=0.68618940391
# delay: 1
# Trial 12, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.717570463519, Delta=0.31381059608999995, Belief State 1[12]=0.717570463519
# delay: 1
# Trial 13, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.7458134171671, Delta=0.282429536481, Belief State 1[13]=0.7458134171671
# delay: 1
# Trial 14, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.7712320754503901, Delta=0.25418658283289997, Belief State 1[14]=0.7712320754503901
# delay: 1
# Trial 15, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.7941088679053511, Delta=0.22876792454960992, Belief State 1[15]=0.7941088679053511
# delay: 1
# Trial 16, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.814697981114816, Delta=0.20589113209464893, Belief State 1[16]=0.814697981114816
# delay: 1
# Trial 17, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.8332281830033343, Delta=0.18530201888518405, Belief State 1[17]=0.8332281830033343
# delay: 1
# Trial 18, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.8499053647030009, Delta=0.16677181699666566, Belief State 1[18]=0.8499053647030009
# delay: 1
# Trial 19, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.8649148282327008, Delta=0.15009463529699907, Belief State 1[19]=0.8649148282327008
# delay: 1
# Trial 20, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.8784233454094308, Delta=0.13508517176729917, Belief State 1[20]=0.8784233454094308
# delay: 1
# Trial 21, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.8905810108684877, Delta=0.12157665459056921, Belief State 1[21]=0.8905810108684877
# delay: 1
# Trial 22, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.901522909781639, Delta=0.10941898913151227, Belief State 1[22]=0.901522909781639
# delay: 1
# Trial 23, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.911370618803475, Delta=0.09847709021836104, Belief State 1[23]=0.911370618803475
# delay: 1
# Trial 24, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.9202335569231275, Delta=0.08862938119652497, Belief State 1[24]=0.9202335569231275
# delay: 1
# Trial 25, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.9282102012308148, Delta=0.07976644307687253, Belief State 1[25]=0.9282102012308148
# delay: 1
# Trial 26, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.9353891811077333, Delta=0.07178979876918523, Belief State 1[26]=0.9353891811077333
# delay: 1
# Trial 27, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.94185026299696, Delta=0.06461081889226672, Belief State 1[27]=0.94185026299696
# delay: 1
# Trial 28, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.947665236697264, Delta=0.05814973700304005, Belief State 1[28]=0.947665236697264
# delay: 1
# Trial 29, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.9528987130275376, Delta=0.05233476330273601, Belief State 1[29]=0.9528987130275376
# delay: 1
# Trial 30, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.9576088417247839, Delta=0.04710128697246241, Belief State 1[30]=0.9576088417247839
# delay: 1
# Trial 31, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.9618479575523055, Delta=0.04239115827521611, Belief State 1[31]=0.9618479575523055
# delay: 1
# Trial 32, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.9656631617970749, Delta=0.038152042447694545, Belief State 1[32]=0.9656631617970749
# delay: 1
# Trial 33, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.9690968456173674, Delta=0.0343368382029251, Belief State 1[33]=0.9690968456173674
# delay: 1
# Trial 34, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.9721871610556306, Delta=0.03090315438263258, Belief State 1[34]=0.9721871610556306
# delay: 1
# Trial 35, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.9749684449500675, Delta=0.027812838944369367, Belief State 1[35]=0.9749684449500675
# delay: 1
# Trial 36, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.9774716004550608, Delta=0.025031555049932486, Belief State 1[36]=0.9774716004550608
# delay: 1
# Trial 37, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.9797244404095546, Delta=0.022528399544939237, Belief State 1[37]=0.9797244404095546
# delay: 1
# Trial 38, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.9817519963685992, Delta=0.020275559590445358, Belief State 1[38]=0.9817519963685992
# delay: 1
# Trial 39, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.9835767967317393, Delta=0.018248003631400778, Belief State 1[39]=0.9835767967317393
# delay: 1
# Trial 40, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.9852191170585654, Delta=0.016423203268260744, Belief State 1[40]=0.9852191170585654
# delay: 1
# Trial 41, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.9866972053527088, Delta=0.014780882941434648, Belief State 1[41]=0.9866972053527088
# delay: 1
# Trial 42, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.9880274848174379, Delta=0.013302794647291227, Belief State 1[42]=0.9880274848174379
# delay: 1
# Trial 43, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.9892247363356941, Delta=0.011972515182562149, Belief State 1[43]=0.9892247363356941
# delay: 1
# Trial 44, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.9903022627021246, Delta=0.010775263664305923, Belief State 1[44]=0.9903022627021246
# delay: 1
# Trial 45, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.9912720364319122, Delta=0.009697737297875375, Belief State 1[45]=0.9912720364319122
# delay: 1
# Trial 46, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.992144832788721, Delta=0.008727963568087804, Belief State 1[46]=0.992144832788721
# delay: 1
# Trial 47, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.9929303495098489, Delta=0.00785516721127899, Belief State 1[47]=0.9929303495098489
# delay: 1
# Trial 48, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.9936373145588641, Delta=0.007069650490151069, Belief State 1[48]=0.9936373145588641
# delay: 1
# Trial 49, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.9942735831029776, Delta=0.00636268544113594, Belief State 1[49]=0.9942735831029776
# delay: 1
# Trial 50, Probability: 1.0, Current State: 0.1, delay: 1.0
# State1: Prediction=0.8948462247926798, Delta=-0.9942735831029776, Belief State 1[50]=0.8948462247926798
# delay: 1
# Trial 51, Probability: 0.9090909090909091, Current State: 0.1, delay: 1.0
# State1: Prediction=0.8053616023134118, Delta=-0.8948462247926798, Belief State 1[51]=0.7321469111940108
# delay: 1
# Trial 52, Probability: 0.16666666666666669, Current State: 1, delay: 0.5
# State2: Prediction=0.0, Delta=0.0, Belief State 2[52]=0
# delay: 1
# Trial 53, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[53]=0
# delay: 1
# Trial 54, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[54]=0
# delay: 1
# Trial 55, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[55]=0
# delay: 1
# Trial 56, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[56]=0
# delay: 1
# Trial 57, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[57]=0
# delay: 1
# Trial 58, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[58]=0
# delay: 1
# Trial 59, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[59]=0
# delay: 1
# Trial 60, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[60]=0
# delay: 1
# Trial 61, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[61]=0
# delay: 1
# Trial 62, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[62]=0
# delay: 1
# Trial 63, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[63]=0
# delay: 1
# Trial 64, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[64]=0
# delay: 1
# Trial 65, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[65]=0
# delay: 1
# Trial 66, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[66]=0
# delay: 1
# Trial 67, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[67]=0
# delay: 1
# Trial 68, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[68]=0
# delay: 1
# Trial 69, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[69]=0
# delay: 1
# Trial 70, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[70]=0
# delay: 1
# Trial 71, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[71]=0
# delay: 1
# Trial 72, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[72]=0
# delay: 1
# Trial 73, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[73]=0
# delay: 1
# Trial 74, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[74]=0
# delay: 1
# Trial 75, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[75]=0
# delay: 1
# Trial 76, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[76]=0
# delay: 1
# Trial 77, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[77]=0
# delay: 1
# Trial 78, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[78]=0
# delay: 1
# Trial 79, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[79]=0
# delay: 1
# Trial 80, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[80]=0
# delay: 1
# Trial 81, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[81]=0
# delay: 1
# Trial 82, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[82]=0
# delay: 1
# Trial 83, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[83]=0
# delay: 1
# Trial 84, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[84]=0
# delay: 1
# Trial 85, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[85]=0
# delay: 1
# Trial 86, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[86]=0
# delay: 1
# Trial 87, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[87]=0
# delay: 1
# Trial 88, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[88]=0
# delay: 1
# Trial 89, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[89]=0
# delay: 1
# Trial 90, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[90]=0
# delay: 1
# Trial 91, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[91]=0
# delay: 1
# Trial 92, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[92]=0
# delay: 1
# Trial 93, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[93]=0
# delay: 1
# Trial 94, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[94]=0
# delay: 1
# Trial 95, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[95]=0
# delay: 1
# Trial 96, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[96]=0
# delay: 1
# Trial 97, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[97]=0
# delay: 1
# Trial 98, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[98]=0
# delay: 1
# Trial 99, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[99]=0
# delay: 1
# Trial 100, Probability: 1.0, Current State: 1, delay: 1.0
# State2: Prediction=0.0, Delta=0.0, Belief State 2[100]=0
# delay: 1
# Trial 101, Probability: 0.5081967213114754, Current State: 1, delay: 0.03225806451612903
# State2: Prediction=0.0, Delta=0.0, Belief State 2[101]=0
